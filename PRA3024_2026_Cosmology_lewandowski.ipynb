# %% [markdown]
# # <span style='color:deepskyblue'> Cosmology MCMC notebook </span>

# %% [markdown]
# ## <span style='color:deepskyblue'>Preliminaries</span>

# %%
# Install required packages (if not available on server, uncomment the lines below)
# !pip3 install --upgrade pip
# !pip3 install getdist
# !pip3 install numpy
# !pip3 install scipy
# !pip3 install matplotlib
# Out:
# Requirement already satisfied: pip in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (26.0.1)
# Requirement already satisfied: getdist in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (1.7.5)
# Requirement already satisfied: numpy>=1.23.0 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from getdist) (2.3.3)
# Requirement already satisfied: matplotlib!=3.5.0,>=2.2.0 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from getdist) (3.10.6)
# Requirement already satisfied: scipy>=1.5 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from getdist) (1.16.2)
# Requirement already satisfied: PyYAML>=5.1 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from getdist) (6.0.3)
# Requirement already satisfied: packaging>=24 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from getdist) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (1.4.9)
# Requirement already satisfied: pillow>=8 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from matplotlib!=3.5.0,>=2.2.0->getdist) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.5.0,>=2.2.0->getdist) (1.17.0)
# Requirement already satisfied: numpy in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (2.3.3)
# Requirement already satisfied: scipy in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (1.16.2)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from scipy) (2.3.3)
# Requirement already satisfied: matplotlib in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\lukas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
 #Load required packages
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.integrate as integrate

# import pylab
import getdist, IPython, time
from numpy import random

# from IPython.display import Image
from getdist import plots, MCSamples, loadMCSamples

# just for printing! calculations should be performed with machine precision
# %precision 3
# Out:
# '%.3f'

# %% [markdown]
# (NB: Those equations that you will need to build your code are those $\boxed{\text{with a box around}}$)
#
# ## <span style='color:deepskyblue'> The Lambda CDM Model </span>
#
# The Lambda-Cold-Dark-Matter ($\Lambda$CDM) Model is our current "Standard" cosmological model. It postulates a Universe that behaves according to **General Relativity**, filled with **baryons** (protons, neutrons - the stuff we and stars are made of!), **Cold Dark Matter (CDM)** and a **Cosmological Constant** $\Lambda$.
#
# The expansion of the Universe is best described in terms of the **scale factor** $a$ (the "radius" of the Universe, conventionally set to 1 today) and the **Hubble rate** $H$
#
# $$
# H \equiv \frac{\dot a}{a}
# $$
# Where the dot signifies a time derivative $\dot a \equiv da/dt $
#
# The Einstein Equations in a **homogeneous and isotropic** Universe have an especially simple form and a special name, **Friedmann Equation**:
#
# $$
# H^2 = \frac{8\pi G}{3}\rho + \frac{k}{a^2}
# $$
#
# where $\rho$ is the total energy density of the Universe (at a certain time or size), and $k$ is a universal constant related to the [spatial curvature and shape of the Universe](https://en.wikipedia.org/wiki/Shape_of_the_universe#:~:text=The%20spatial%20curvature%20is%20related,indistinguishable%20spaces%20with%20different%20topologies.). In the $\Lambda$CDM model (and at late enough times), this additionally simplifies to
#
# $$
# \boxed{
# H^2 = H_0^2\left(\Omega_\Lambda + \Omega_m a^{-3} + \Omega_k a^{-2}\right)
# }
# \qquad
# \qquad
# \boxed{
# \Omega_m + \Omega_\Lambda + \Omega_k = 1
# }
# $$
#
# $H_0$ is the value of the Hubble rate *today*, and the parameters $\Omega_m$, $\Omega_\Lambda$ and $\Omega_k$ are dimensionless quantities indicating how much of the present expansion of the Universe is due to (non-relativistic) matter, cosmological constant $\Lambda$, and spatial curvature $k$. Note that the three $\Omega$'s are *not independent* (their sum is 1) and that we grouped together the contribution of baryons and CDM,
#
# $$
# \Omega_m = \Omega_{\rm CDM} + \Omega_{\rm b}
# $$
#
# and that we have evidence that independent evidence that $\Omega_b \approx 5$\%. Note that only $\Omega_m \geq 0$ makes physical sense, while in principle both $\Omega_\Lambda$ and $\Omega_k$ can be negative.
# In this consideration we are neglecting the contribution of the radiation which becomes negligable after the early stages of expansion.
#
#
# The present Hubble rate is conventionally parametrised in terms of the dimensionless $h$:
#
# $$
# H_0 \equiv h\, \times 100 \left[\frac{ \,\text{km}}{\text{s Mpc}}\right]
# $$
#
# where Mpc = Megaparsec and [parsec](https://en.wikipedia.org/wiki/Parsec)  $pc = 3.086 \cdot 10^{16}$ m.
#
# In essence, these equations give us the relation between *what exists in the Universe* and *how the Universe expanded*. Measure one, I can tell you the other. This is precisely what we aim to do!
#
# Time to define the function $H(z)$. Don't forget to include the useful parameters as arguments of the function, and to define `parsec`.

# %% [markdown]
# ## <span style='color:orange'> Exercise 1 </span>
#
# Write your own code for the Hubble parameter as a function of redshift (z) note that $a = \frac{1}{1+z}$. Make a plot to see if your function works as expected.

# %%
# Define parsec
pc = 3.086 * 10**16
Mpc = pc/10**6
a = 1
# Define test values
H0= 70
omega_l =0.6
omega_m =0.3
omega_k = 0.1
# Redshift range
z = np.linspace(0, 10, 200)

# Hubble rate as a function of redshift
def Hubble(H0, omega_l, omega_m, omega_k, z ):
    H_z = H0 * np.sqrt(omega_l + omega_k*(1+z)**2 + omega_m*(1+z)**3)
    omega_m = 1 - omega_l - omega_k
    return H_z

# Evaluate the Hubble rate over redshift range
H_z = Hubble(H0, omega_l, omega_m, omega_k, z)

# Plot H(z) vs redshift
fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(z, H_z, color="royalblue", linewidth=2, label=f"H(z)  [Ωm={omega_m}, ΩΛ={omega_l}, Ωk={omega_k}]")

ax.set_xlabel("Redshift z", fontsize=13)
ax.set_ylabel("H(z)  [km/s/Mpc]", fontsize=13)
ax.set_title("Hubble Rate as a Function of Redshift", fontsize=15)
ax.legend(fontsize=12)
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##  <span style='color:deepskyblue'>Supernovae Ia</span>
#
# In order to track the expansion of the Universe, we will look at Supernovae type Ia observations. SNIa are formed when a *white dwarf* accretes matter from a companion until it reaches a critical mass of about $1.44 M_\odot$ (solar masses), after which it explodes **at always the same luminosity** $L_{\rm SN}$. Therefore, the observed [magnitude](https://en.wikipedia.org/wiki/Magnitude_(astronomy)) is only a function of their [**luminosity distance**](https://en.wikipedia.org/wiki/Distance_measures_(cosmology)) from Earth, defined as the ratio of the intrinsic luminosity $L_{\rm SNIa}$ and the measured *surface brightness* $\Phi$ (energy per unit time per unit area)
#
# $$ d_L\equiv \frac{L_{\rm SN}}{4\pi \Phi} $$
#
# While photons (light rays) travel from the distant SNIa to Earth, the Universe expands and the photons get redshifted, and this redshift is directly related to the size of the Universe when the photon was emitted compared to today:
#
# $$ \frac{\lambda_{\rm obs}}{\lambda_{\rm em}} \equiv 1 + z_{\rm em} = \frac{1}{a_{\rm em}}$$
#
# We can express the luminosity distance in terms of the Hubble rate:
#
# $$
# \boxed{
# d_L(z) = \frac{c}{H_0}(1+z) \times
# \begin{cases}
#     \cfrac{1}{\sqrt{\Omega_k}} \,\sinh\left(\sqrt{\Omega_k}\,D(z)\right) & \Omega_k > 0
#     \\[.5em]
#     D(z) & \Omega_k = 0
#     \\[.5em]
#     \cfrac{1}{\sqrt{-\Omega_k}} \,\sin\left(\sqrt{-\Omega_k}\,D(z)\right) & \Omega_k < 0
# \end{cases}
# \qquad\qquad
# D(z) \equiv H_0\int_0^z \frac{{\rm d}Z}{H(Z)}
# }
# $$
#
# where $c$ is the speed of light: $c \simeq 2.998 \cdot 10^{5}$ km/s.
#
# Clearly, there exists a relation between $d_L(z)$ and $H(z)$, so the luminosity distance is a useful measure of the Universe expansion history.
#
# We can create the function `dL(z, h, Omega_m, Omega_Lambda)`. You can also pass the function `Hubble` as an argument: `dL(z, Hubble, Omega_m, Omega_Lambda)`. Additionally, you can create $D(z)$ for your convenience.
#
# Note that you need to integrate the function $H(z)$, so write your own quick-and-easy numerical integrator, for example implementin the [trapezoidal rule](https://en.wikipedia.org/wiki/Trapezoidal_rule) or your favourite alternative, or [look up the pre-written methods](https://docs.scipy.org/doc/scipy/reference/tutorial/integrate.html). Make sure it returns $d_L$ in parsecs and that it uses $h$, which is $H_0$ measured in units of 100 km/s/Mpc!

# %% [markdown]
# ## <span style='color:orange'> Exercise 2 </span>
#
# Define a function that calculate the luminosty distance in flat ($\Omega_k = 0$) and both positively and negatively curved  ($\Omega_k \neq 0$) spacetime.

# %%
from scipy import integrate

c = 2.998e5  # Speed of light [km/s]

def theor_luminosity_distance(H0, omega_l, omega_m, omega_k, z):
    """
    Compute the luminosity distance d_L(z) for a given cosmology.

    Parameters
    ----------
    H0      : Hubble constant [km/s/Mpc]
    omega_l : Dark energy density parameter
    omega_m : Matter density parameter
    omega_k : Curvature density parameter
    z       : Redshift (scalar or array)"""

    def integrand(Z):
        """Integrand dZ/H(Z)"""
        return 1.0 / Hubble(H0, omega_l, omega_m, omega_k, Z)

    def compute_single(z_val):
        """Compute d_L for a single redshift value"""

        # D(z) = H0 * integral from 0 to z of dZ/H(Z)
        integral, _ = integrate.quad(integrand, 0, z_val)
        D = H0 * integral

        # Apply the correct formula depending on curvature
        if omega_k > 0:
            # Open universe — hyperbolic geometry
            comoving = (1.0 / np.sqrt(omega_k)) * np.sinh(np.sqrt(omega_k) * D)
        elif omega_k == 0:
            # Flat universe — Euclidean geometry
            comoving = D
        else:
            # Closed universe — spherical geometry
            comoving = (1.0 / np.sqrt(-omega_k)) * np.sin(np.sqrt(-omega_k) * D)

        # Luminosity distance: d_L = (c/H0) * (1+z) * comoving
        d_L = (c / H0) * (1 + z_val) * comoving

        """ This handles all three curvature cases:
      Omega_k > 0 : open universe  -> (1/sqrt(Omega_k))  * sinh(sqrt(Omega_k)  * D(z))
      Omega_k = 0 : flat universe  -> D(z)
      Omega_k < 0 : closed universe-> (1/sqrt(-Omega_k)) * sin(sqrt(-Omega_k)  * D(z)) 
        where D(z) = H0 * integral from 0 to z of dZ/H(Z).

         Returns
        -------
        d_L : Luminosity distance [Mpc]
        """
        return d_L

    # Handle both scalar and array inputs
    if np.isscalar(z):
        return compute_single(z)
    else:
        return np.array([compute_single(z_val) for z_val in z])


# Test all three curvature cases
z = np.linspace(0.01, 10, 200)   # avoid z=0 to prevent trivial zero

# Flat universe (Omega_k = 0)
d_L_flat   = theor_luminosity_distance(H0, omega_l=0.7, omega_m=0.3, omega_k=0.0,  z=z)

# Open universe (Omega_k > 0)
d_L_open   = theor_luminosity_distance(H0, omega_l=0.6, omega_m=0.3, omega_k=0.1,  z=z)

# Closed universe (Omega_k < 0)
d_L_closed = theor_luminosity_distance(H0, omega_l=0.8, omega_m=0.3, omega_k=-0.1, z=z)

# Plot all three cases
fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(z, d_L_flat,   color="royalblue", linewidth=2, label="Flat   (Ωk = 0.0)")
ax.plot(z, d_L_open,   color="crimson",   linewidth=2, label="Open   (Ωk = +0.1)")
ax.plot(z, d_L_closed, color="green",     linewidth=2, label="Closed (Ωk = −0.1)")

ax.set_xlabel("Redshift z", fontsize=13)
ax.set_ylabel("Luminosity Distance [Mpc]", fontsize=13)
ax.set_title("Luminosity Distance vs Redshift for Different Curvatures", fontsize=14)
ax.legend(fontsize=12)
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Print d_L at a few redshifts for the flat case
print("Flat universe luminosity distances:")
for z_val in [0.1, 0.5, 1.0, 2.0, 5.0]:
    d = theor_luminosity_distance(H0, omega_l=0.7, omega_m=0.3, omega_k=0.0, z=z_val)
    print(f"  z = {z_val:.1f} -> d_L = {d:.1f} Mpc")
# Out:
# Flat universe luminosity distances:
#   z = 0.1 -> d_L = 460.3 Mpc
#   z = 0.5 -> d_L = 2833.0 Mpc
#   z = 1.0 -> d_L = 6607.8 Mpc
#   z = 2.0 -> d_L = 15540.0 Mpc
#   z = 5.0 -> d_L = 46653.4 Mpc

# %% [markdown]
# ## <span style='color:deepskyblue'>The Union2.1 Compilation</span>
#
# Our source of data is from [Union2.1](http://supernova.lbl.gov/Union/). It is a collection of $580$ SNIa, each observation is comprised of redshift $z$ and [distance modulus](https://en.wikipedia.org/wiki/Distance_modulus) $\mu$ (and corresponding errors $\delta\mu$), defined as the difference between the *apparent magnitude* $m$ and the *absolute magnitude* $M$:
#
# $$
# \boxed{
# \mu(z) \equiv m(z) - M \equiv 5 \log_{10} \frac{d_L(z)}{10\,\text{pc}}
# }
# $$
#
# Our goal today is to use SNIa measurements to constrain the parameters ($h, \Omega_\Lambda, \Omega_m$).
#
# In essence, we can calculate for each redshift the theoretical value of $\mu$ using this equation with the expression for $d_L(z)$ and our model of choice $H(z)$ -- note that we will need to perform a numerical integral! -- and compare this value with observations. A different model would amount to changing the theoretical value of $H(z)$.
#
# Let us start by importing and plotting the data:

# %%
# Format is: [name, redshift, distance modulus, error, another number]
data = np.genfromtxt("SCPUnion2.1_mu_vs_z.txt")

# Print the first row as an example
display(data[0])
# Out:
# array([           nan, 2.84880000e-02, 3.53465834e+01, 2.23905933e-01,
#        1.28418942e-01])

# %%
# Extract the redshifts (zs), distance modulus (dist_mod) and magnitude estimated errors (err_dist_mod)
# Data are in columns, so we either slice it by columns: arr[:,n]...
zs = data[:,1] # redshift
print(len(zs))
# ...or transpose the array and then slice by row: arr_transposed[n]
distance_modulus = data.T[2] # distance modulus
error_distance_modulus = data.T[3] # errors on distance modulus = sigmas
# Out:
# 580

# %%
# Let's look at the data, just for fun.
# We can look both at the raw data (distance modulus) or calculate the luminosity distance
# Note that Numpy allows us to manipulate whole arrays at once with something like:
#     array_2 = some_function_of(array_1)

# luminosity distance in pc
luminosity_distance_pc = 10. * 10.**(distance_modulus / 5.)

# and in Mpc
luminosity_distance_Mpc = luminosity_distance_pc / 10.**6

# and the error on that distance:
error_luminosity_distance_Mpc = 5. * (10.**((distance_modulus + error_distance_modulus)/5.-6.) - 10.**((distance_modulus - error_distance_modulus)/5.-6.))

# %% [markdown]
# Recommendation: plot the data so you can see the luminosity distance and distance modulus as a function of the redshift

# %%
# %matplotlib inline

# %% [markdown]
# ## <span style='color:orange'> Exercise 3 </span>
#
# Now also define a function to calculate the distance modulus using your previously defined luminosity distance function. Use these functions to plot the theoretical curves as a function of redshift and compare with the data. (Does the line go through the data points?)

# %%
# Define theoretical distance modulus 
def theor_distance_modulus(z, H0, omega_l, omega_m, omega_k):
    """
    Theoretical distance modulus mu(z) from luminosity distance.
    mu = 5 * log10(d_L [Mpc]) + 25
    """
    d_L = theor_luminosity_distance(H0, omega_l, omega_m, omega_k, z)
    return 5 * np.log10(d_L) + 25

# Smooth redshift array for theoretical curves 
z_theory = np.linspace(0.01, 2.0, 300)

# Compute theory for the requested cosmology: Omega_m=0.3, Omega_L=0.7, h=0.7
# H0 = h * 100 = 70 km/s/Mpc
H0      = 70    # h = 0.7
omega_m = 0.3
omega_l = 0.7
omega_k = 0.0   # flat universe

mu_theory   = theor_distance_modulus(z_theory, H0, omega_l, omega_m, omega_k)
d_L_theory  = theor_luminosity_distance(H0, omega_l, omega_m, omega_k, z_theory)

# %% [markdown]
# Try your functions here. Make atleast two plots to check that for $\Omega_m = 0.3$, $\Omega_\Lambda = 0.7$ and $h =0.7$ your theory calculations of the luminosity distance and the distance modulus match okay to the data for redshifts ranging from ~0.1 to 2.

# %%
# Plot 1: Distance Modulus vs Redshift 
fig, ax = plt.subplots(figsize=(10, 6))

# Supernova data with error bars
ax.errorbar(zs, distance_modulus, yerr=error_distance_modulus,
            fmt='k.', markersize=4, alpha=0.5, label="SCPUnion2.1 data")

# Theoretical curve
ax.plot(z_theory, mu_theory, color="royalblue", linewidth=2,
        label=f"Theory: Ωm={omega_m}, ΩΛ={omega_l}, h=0.7")

ax.set_xlabel("Redshift z", fontsize=13)
ax.set_ylabel("Distance Modulus μ", fontsize=13)
ax.set_title("Distance Modulus vs Redshift", fontsize=14)
ax.legend(fontsize=12)
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Plot 2: Luminosity Distance vs Redshift
fig, ax = plt.subplots(figsize=(10, 6))

# Observed luminosity distances from data
ax.errorbar(zs, luminosity_distance_Mpc, yerr=error_luminosity_distance_Mpc,
            fmt='k.', markersize=4, alpha=0.5, label="SCPUnion2.1 data")

# Theoretical luminosity distance curve
ax.plot(z_theory, d_L_theory, color="crimson", linewidth=2,
        label=f"Theory: Ωm={omega_m}, ΩΛ={omega_l}, h=0.7")

ax.set_xlabel("Redshift z", fontsize=13)
ax.set_ylabel("Luminosity Distance [Mpc]", fontsize=13)
ax.set_title("Luminosity Distance vs Redshift", fontsize=14)
ax.legend(fontsize=12)
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# %matplotlib inline

# %% [markdown]
# ## <span style='color:deepskyblue'>Bayes' Theorem: Likelihood, Prior, Posterior (and Evidence...)</span>
#
# The **conditional probability of A given that B is true** is denoted with $P(A|B)$ (read: *probability of A given B*).
# Did A happen? Then B has probability $P(B|A)$ of happening.
#
# [**Bayes' Theorem**](https://en.wikipedia.org/wiki/Bayes%27_theorem) is simply a reflection of the symmetry of the concept of joint probability:
#
# $$
# P(A|B)P(B) = P(B|A)P(A)
# $$
#
# In physics, our goal is often to determine how likely the values of some parameters $\theta$ are, given how well they reproduce the data $D$.
# We write Bayes' theorem in the following equivalent form:
#
# $$
# P(\theta | D) = \frac{P(D|\theta)P(\theta)}{P(D)}
# $$
#
# The various terms conventionally take the names:
#
# $$
# \begin{aligned}
# P(\theta | D) & && \text{Posterior}
# \\
# P(D | \theta)& && \text{Likelihood}
# \\
# P(\theta) & && \text{Prior}
# \\
# P(D) & && \text{Evidence}
# \end{aligned}
# $$
#
# ### <span style='color:deepskyblue'>Prior</span>
#
# The *prior* quantifies our degree of prior belief in the model parameters. It can contain the results of previous experiments, or theoretical considerations (for instance, that certain parameters cannot be negative, etc.).
#
# We can have *strong priors* about something - the Sun still existing at night, see the comic below - or not.
# When we do *not* have compelling prior knowledge about a parameter, we generally use a *non-informative* prior probability distribution, most often related to the [uniform distribution](https://en.wikipedia.org/wiki/Continuous_uniform_distribution)
#
# $$
# \begin{aligned}
#     \text{Uniform} & && \theta \in \text{Uniform}[\theta_{\rm min}, \theta_{\rm max}]
#     \\
#     \text{Log Uniform} & && \log\theta \in \text{Uniform}[\log\theta_{\rm min}, \log\theta_{\rm max}]
# \end{aligned}
# $$
#
# You may sometimes hear that "the prior doesn't matter". While this is not strictly true, it is however true that in many instances the *likelihood* depends more dramatically on the parameters and will have a dominating contribution to the posterior. You are more than welcome to try different priors for the model parameters and see if and how your results change.
#
# ### <span style='color:deepskyblue'>Likelihood</span>
#
# The measure of how well our model reproduces the data is the **likelihood** $\mathcal L$. For normal (=Gaussian), uncorrelated data $\mu_i$ with errors $\sigma_i$ ($i = \{1,580\}$), the likelihood is related to the famous [**chi-squared**](https://en.wikipedia.org/wiki/Chi-square_distribution) via
#
# $$
# P(D | \theta) \equiv \mathcal L = \exp\left(-\frac{\chi^2}{2}\right)
# \qquad
# \qquad
# \boxed{
# \chi^2 \equiv \sum_{i=1}^{580} \frac{\left(\mu_i^{(\rm theor)} - \mu_i^{(\rm obs)}\right)^2}{\sigma_i^2}
# }
# $$
#
# A *high likelihood* corresponds to a *low chi squared*.
#
# In principle, we could attack the problem brute-force: create a grid of values for $h$, $\Omega_m$, $\Omega_\Lambda$, calculate the likelihood for each combination, and create a profile for the likelihood.
#
# In practical cases, however, this is not only sub-optimal but sometimes **impossible**. Think of complicated models with 20+ free parameters (this is not that unusual in physics, by the way). Even a very coarse grained grid of 100 values for each parameter would result in more than$10^{40}$ (!!!) different parameter combination to be tested. You can probably understand why this is undesirable.
#
# ### <span style='color:deepskyblue'>Evidence</span>
#
# This is the tricky bit. The evidence, which is "*the probability of observing certain data*", is not something that is easy to evaluate or interpret. This looks like a serious limitation to finding the:
#
#
# ### <span style='color:deepskyblue'>Posterior</span>
#
# What does the data tell us about the model parameters? The answer is the *posterior probability distribution*, often (but not necessarily) expressed as (average $\pm$ standard deviation)
#
# $$
# \theta_i = \bar\theta_i \pm \sigma_i
# $$
#
# In other words, the posterior tells us how likely it is for the model parameters to have certain values, *given that we observe the data* $D$.
#
# *This is the final goal of our analysis!*
#
# <br>
#
# ![title](http://1.bp.blogspot.com/-tTx4HDejSww/ULcTeK9_V_I/AAAAAAAAA8g/PCYOH-eXGbk/s1600/frequentists_vs_bayesians.png)
# ![title](https://i.redd.it/5r0hwixt0m931.jpg)

# %% [markdown]
# ## <span style='color:deepskyblue'>Markov-Chain Monte Carlo</span>
#
# Markov-Chain Monte Carlo techniques are a class of methods to sample a probability distribution $P(x)$ - in our case $P(\theta | D)$ - provided that we can calculate a density $\mathcal F(x)$ **that is proportional to it** - in our case $P(\theta)P(D|\theta)$ = likelihood $\times$ prior. Among these, a very popular one is the [**Metropolis-Hastings**](https://en.wikipedia.org/wiki/Metropolis%E2%80%93Hastings_algorithm) algorithm, which is what we will use.
#
# Schematically, the algorithm works as follows:
# * Start with an $n$-tuple of parameters $\theta_{\rm old} = \{\theta_1, \theta_2, \dots\}_{\rm old}$ (in our case $\theta = \{h,\Omega_m,\Omega_\Lambda\}$) and calculate the $\mathcal F_{\rm old}$
# * Propose a new set of parameters $\theta_{\rm prop}$, calculate the new corresponding $\mathcal F_{\rm prop}$. How you propose the new parameters is not essential as long as the probability of going from one set of parameters to the next is the same as the inverse: $P(\theta_a \to \theta_b) = P(\theta_b \to \theta_a)$. For this, we normally take Gaussian displacements with some (relatively small) standard deviation.
# * Compare the new and old likelihoods-priors:
#     * If $\mathcal F_{\rm prop} > \mathcal F_{\rm old}$, accept the step: $\theta_{\rm new} = \theta_{\rm prop}$
#     * Otherwise, accept with probability $P_{\rm accept} = \mathcal F_{\rm prop}/\mathcal F_{\rm old}$
# * If accepted, $\theta_{\rm new} = \theta_{\rm prop}$ and record the step; otherwise, $\theta_{\rm new} = \theta_{\rm old}$ (no re-recording)
# * Update $\theta_{\rm old} = \theta_{\rm new}$
# * Repeat
#
# The MC chain keeps going until the desired number of steps or, ideally, when a suitable convergence test, like for example the [Gelman-Rubin test](https://bookdown.org/rdpeng/advstatcomp/monitoring-convergence.html), is satisfied.
# Today we will just set a limit to the total number of steps, but please feel free to implement and test your favourite convergence test!
#
# Looking at equation (4), you can convince yourself that
# $$
# \frac{\mathcal L_a}{\mathcal L_b} = \exp\left(\frac{\chi_b^2 - \chi_a^2}{2}\right)
# $$
#
# (This is useful because $\chi^2$ can be large, so we want to avoid the likelihoods evaluating to `0.` -- computers don't like dividing by zero, unfortunately)
#
# * Start with an $n$-tuple of parameters $\theta_{\rm old} = \{\theta_1, \theta_2, \dots\}_{\rm old}$ (in our case $\theta = \{h,\Omega_m,\Omega_\Lambda\}$) and the corresponding chi squared $\chi_{\rm old}^2$ (to be clear, for us this implies calculating a series of 580 integrals and comparing each with the observed values)
# * Propose new parameters $\theta_{\rm prop}$ and calculate the corresponding chi squared $\chi_{\rm prop}^2$
# * Draw a random number $r \in [0,1]$
# * Accept the step if
# $$
# r < \exp\left(\frac{\chi_{\rm old}^2 - \chi_{\rm prop}^2}{2}\right) \frac{P(\theta)_{\rm prop}}{P(\theta)_{\rm old}}
# $$
# * If accepted, update $\theta_{\rm old} = \theta_{\rm prop}$, and record; otherwise, $\theta_{\rm new} = \theta_{\rm old}$ (no re-recording)
# * Repeat

# %% [markdown]
# ##  <span style='color:orange'> Exercise 4 </span>
#
# Write your own code to perform a Monte Carlo Markov Chain. Note that your algorithm should be robust and converge to the correct parameters even for poor initial guesses.

# %%
from random import random
from random import gauss
import sys
import time

def calculate_chi2(params):
    """
    Calculate chi-squared between the theoretical distance modulus
    and the supernova data for a given set of cosmological parameters.

    chi2 = sum( (mu_obs - mu_theory)^2 / sigma^2 )

    Parameters
    ----------
    params : list [H0, omega_l, omega_m, omega_k]

    Returns
    -------
    chi2 : float
    """
    H0, omega_l, omega_m, omega_k = params

    # Compute theoretical distance modulus at each observed redshift
    mu_theory = theor_distance_modulus(zs, H0, omega_l, omega_m, omega_k)

    # Chi-squared: sum of squared residuals weighted by measurement errors
    chi2 = np.sum(((distance_modulus - mu_theory) / error_distance_modulus)**2)

    return chi2


#  Output file to store the chain 
filename = "MC_Chain_SNIa.txt"
file     = open(filename, "w")
file.write("H0\tomega_l\tomega_m\tomega_k\tchi2\n")  # header line

# Initial parameter guesses
# Start near the expected values — MCMC should converge even from poor guesses
H0_cur      = 70.0   # Hubble constant [km/s/Mpc]
omega_l_cur = 0.5    # dark energy — deliberately off from 0.7 to test convergence
omega_m_cur = 0.5    # matter — deliberately off from 0.3
omega_k_cur = 0.0    # keep flat (curvature poorly constrained by SNIa alone)

# Step sizes for the Gaussian proposal distribution
# Too large -> low acceptance rate; too small -> slow exploration
step_H0      = 1.0
step_omega_l = 0.05
step_omega_m = 0.05
step_omega_k = 0.01

# Number of MCMC iterations
N_total = 10000

# Compute chi2 at the starting point
chi2_cur = calculate_chi2([H0_cur, omega_l_cur, omega_m_cur, omega_k_cur])

# Counters for acceptance rate
N_steps = 0   # accepted steps
total   = 0   # total proposed steps

print("Progress: ")
start = time.time()

# Metropolis-Hastings MCMC loop
for i in range(N_total):

    total += 1

    # Print progress every 500 steps
    if i % 500 == 0:
        print(f"  Step {i}/{N_total}  | chi2 = {chi2_cur:.2f} | "
              f"acceptance = {N_steps/(total):.2%}")

    # Propose new parameters by stepping in a random Gaussian direction
    # gauss(mean, sigma) draws from normal distribution
    H0_prop      = gauss(H0_cur,      step_H0)
    omega_l_prop = gauss(omega_l_cur, step_omega_l)
    omega_m_prop = gauss(omega_m_cur, step_omega_m)
    omega_k_prop = gauss(omega_k_cur, step_omega_k)

    # Reject unphysical proposals outright — densities must be positive
    if omega_l_prop < 0 or omega_m_prop < 0 or H0_prop < 0:
        continue

    # Compute chi2 at proposed point
    chi2_prop = calculate_chi2([H0_prop, omega_l_prop, omega_m_prop, omega_k_prop])

    # Metropolis-Hastings acceptance criterion
    # Always accept if chi2 improved (delta_chi2 < 0)
    # Accept with probability exp(-delta_chi2/2) if chi2 worsened
    delta_chi2 = chi2_prop - chi2_cur

    if delta_chi2 < 0:
        # New point is better — always accept
        accept = True
    else:
        # New point is worse — accept with probability exp(-delta/2)
        accept = random() < np.exp(-delta_chi2 / 2.0)

    if accept:
        # Move to the new point
        H0_cur      = H0_prop
        omega_l_cur = omega_l_prop
        omega_m_cur = omega_m_prop
        omega_k_cur = omega_k_prop
        chi2_cur    = chi2_prop
        N_steps    += 1

    # Write current state to file regardless of acceptance
    # (writing current = autocorrelation in chain, expected)
    file.write(f"{H0_cur:.4f}\t{omega_l_cur:.4f}\t{omega_m_cur:.4f}\t"
               f"{omega_k_cur:.4f}\t{chi2_cur:.4f}\n")

print(f"Done! Acceptance ratio = {N_steps/total:.3f}")
file.close()

end = time.time()
print(f"Time required: {end-start:.2f} s")

# Quick summary of results 
# Load the chain back and print best-fit values
chain = np.genfromtxt(filename, names=True)

# Discard first 20% of chain 
burn_in = int(0.2 * len(chain))
chain   = chain[burn_in:]

print(f"\nBest fit parameters (posterior mean ± std)")
print(f"  H0      = {chain['H0'].mean():.2f}      ± {chain['H0'].std():.2f}      km/s/Mpc")
print(f"  Omega_L = {chain['omega_l'].mean():.4f} ± {chain['omega_l'].std():.4f}")
print(f"  Omega_m = {chain['omega_m'].mean():.4f} ± {chain['omega_m'].std():.4f}")
print(f"  Omega_k = {chain['omega_k'].mean():.4f} ± {chain['omega_k'].std():.4f}")
# Out:
# Progress:
#   Step 0/10000  | chi2 = 783.09 | acceptance = 0.00%
#   Step 500/10000  | chi2 = 562.38 | acceptance = 7.58%
#   Step 1000/10000  | chi2 = 563.21 | acceptance = 6.29%
#   Step 1500/10000  | chi2 = 570.55 | acceptance = 6.13%
#   Step 2000/10000  | chi2 = 564.01 | acceptance = 5.55%
#   Step 2500/10000  | chi2 = 566.49 | acceptance = 5.08%
#   Step 3000/10000  | chi2 = 568.57 | acceptance = 4.97%
#   Step 3500/10000  | chi2 = 565.48 | acceptance = 4.66%
#   Step 4000/10000  | chi2 = 569.15 | acceptance = 4.95%
#   Step 4500/10000  | chi2 = 565.22 | acceptance = 5.18%
#   Step 5000/10000  | chi2 = 567.68 | acceptance = 5.26%
#   Step 5500/10000  | chi2 = 567.50 | acceptance = 5.45%
#   Step 6000/10000  | chi2 = 563.02 | acceptance = 5.58%
#   Step 6500/10000  | chi2 = 566.10 | acceptance = 5.83%
#   Step 7000/10000  | chi2 = 566.09 | acceptance = 6.03%
#   Step 7500/10000  | chi2 = 565.83 | acceptance = 6.21%
#   Step 8000/10000  | chi2 = 566.06 | acceptance = 6.46%
#   Step 8500/10000  | chi2 = 563.27 | acceptance = 6.73%
#   Step 9000/10000  | chi2 = 564.10 | acceptance = 6.99%
#   Step 9500/10000  | chi2 = 566.91 | acceptance = 6.93%
# Done! Acceptance ratio = 0.069
# Time required: 530.19 s
#
# Best fit parameters (posterior mean ± std)
#   H0      = 68.22      ± 8.45      km/s/Mpc
#   Omega_L = 0.6958 ± 0.2415
#   Omega_m = 0.2523 ± 0.1057
#   Omega_k = 0.1473 ± 0.0867

# %% [markdown]
# After completion of the programme, your MC chain will (*hopefully*) look something like this:
#
# `#Omega_m  Omega_L  h`
#
# `0.297     0.703    0.698`
#
# `0.285     0.715    0.701`
#
# `0.288     0.712    0.699`
#
# `...`

# %% [markdown]
# ## <span style='color:deepskyblue'>Plotting: GetDist</span>
#
# We will do the plots with [`GetDist`](https://getdist.readthedocs.io/en/latest/plot_gallery.html).
#
# The plot gallery contains a lot of useful examples, you should be able to read them fairly easily and see which applies to your situation. Look for both (triangle) plots and for parameter estimation.
#
# Note that many `GetDist` functions require arguments of type `MCSamples`; make sure you convert your lists accordingly.

# %% [markdown]
# ##  <span style='color:orange'> Exercise 5 </span>
#
# Use the GetDist functions in the example given underneath but with your **own** MCMC data to generate investigate the sampling of the MCMC.

# %%
filename = "MC_Chain_SNIa.txt"
datafile = np.loadtxt(filename,
                      skiprows=int(0.3 * N_steps)) # remove some burn-in

h, OmegaM, OmegaL, chi2 = datafile[:,1], datafile[:,2], datafile[:,3], datafile[:,4]

# You can easily create new np.arrays that are functions of other np.arrays
Omegak = 1. - OmegaM - OmegaL

# Let's define variable names and labels
my_labels = [r'h', r'\Omega_m', r'\Omega_\Lambda', r'\Omega_k']
my_names = ['h', 'OmegaM', 'OmegaL', 'Omegak']
my_dim = len(my_names) # The number of variables we're plotting

# This creates a higher-dimensional array with all our data, shaped in the appropriate way...
my_samples = np.transpose(np.reshape([h, OmegaM, OmegaL, Omegak], (my_dim, len(h))))
print(np.shape(my_samples))

# ... to create an "MCSamples" data type, which GetDist can use
my_samples = MCSamples(samples = my_samples, labels = my_labels, names = my_names)

# The usual 1-sigma confidence level. You can change to 2- or 3-sigma if you want
conf_level = 0.6827

# This prints a table with the 1D posteriors (confidence levels)
for nam in my_names:
    print(round(my_samples.confidence(nam,(1.-conf_level)/2.,upper=False),2), \
          " < ", nam , " < ", round(my_samples.confidence(nam,(1.-conf_level)/2.,upper=True),2),\
          " at " , int(100*conf_level),"\b% CL")
print("\n")

#Triangle corner plot
j = plots.getSubplotPlotter(subplot_size=3)
j.settings.axes_labelsize = 22
j.settings.axes_fontsize = 16
j.triangle_plot(my_samples, filled = True, title_limit=1)
# Out:
# (9789, 4)
# Removed no burn in
# 0.45  <  h  <  0.97  at  68% CL
# 0.15  <  OmegaM  <  0.35  at  68% CL
# 0.04  <  OmegaL  <  0.22  at  68% CL
# 0.54  <  Omegak  <  0.69  at  68% CL
# WARNING:root:auto bandwidth for h very small or failed (h=0.0006527056133569237,N_eff=1076.033170008934). Using fallback (h=0.04001026414078433)
# WARNING:root:auto bandwidth for h very small or failed (h=0.0006527056133569237,N_eff=1076.033170008934). Using fallback (h=0.04001026414078433)
# WARNING:root:auto bandwidth for OmegaL very small or failed (h=0.0006078280033667736,N_eff=1078.9543000241201). Using fallback (h=0.04152954115905746)
# WARNING:root:auto bandwidth for OmegaL very small or failed (h=0.0006078280033667736,N_eff=1078.9543000241201). Using fallback (h=0.04152954115905746)
# WARNING:root:fine_bins_2D not large enough for optimal density: h, OmegaM
# WARNING:root:fine_bins_2D not large enough for optimal density: h, OmegaL
# WARNING:root:fine_bins_2D not large enough for optimal density: h, Omegak
# WARNING:root:fine_bins_2D not large enough for optimal density: OmegaM, OmegaL
# WARNING:root:fine_bins_2D not large enough for optimal density: OmegaM, Omegak
# WARNING:root:fine_bins_2D not large enough for optimal density: OmegaL, Omegak

# %%
print(my_samples.getParamNames())
# Out:
# h	h
# OmegaM	\Omega_m
# OmegaL	\Omega_\Lambda
# Omegak	\Omega_k

# %% [markdown]
# ##  <span style='color:orange'> Exercise 6 </span>
#
# Show the curves for $d_L$ and/or $\mu$ as a function of redshift using the best fit parameters determined using your MCMC code, so you will need to make use of your earlier defined functions for $d_L$ and $\mu$ . Check if this correctly reproduces the data. Additionally, provide an extimate on the error and plot the corresponding confidence intervals based on the sample that your MCMC code produces.

# %%
# Plot MCMC Best Fit with Confidence Intervals

# Load MCMC chain (removing burn-in)
filename = "MC_Chain_SNIa.txt"
datafile = np.loadtxt(filename, skiprows=1)  # Skip header row

H0_chain = datafile[:, 0]
omega_l_chain = datafile[:, 1]
omega_m_chain = datafile[:, 2]
omega_k_chain = datafile[:, 3]

# Remove first 30% as burn-in
burn_in = int(0.3 * len(H0_chain))
H0_chain = H0_chain[burn_in:]
omega_l_chain = omega_l_chain[burn_in:]
omega_m_chain = omega_m_chain[burn_in:]
omega_k_chain = omega_k_chain[burn_in:]

print(f"Using {len(H0_chain)} MCMC samples (after burn-in)\n")

# Calculate best fit parameters (posterior means)
H0_best = np.mean(H0_chain)
omega_l_best = np.mean(omega_l_chain)
omega_m_best = np.mean(omega_m_chain)
omega_k_best = np.mean(omega_k_chain)

print("Best Fit Parameters:")
print(f"  H0  = {H0_best:.2f} ± {np.std(H0_chain):.2f} km/s/Mpc")
print(f"  Ω_Λ = {omega_l_best:.4f} ± {np.std(omega_l_chain):.4f}")
print(f"  Ω_M = {omega_m_best:.4f} ± {np.std(omega_m_chain):.4f}")
print(f"  Ω_k = {omega_k_best:.4f} ± {np.std(omega_k_chain):.4f}\n")

# Create fine redshift grid for smooth curve
z_theory = np.linspace(0.01, zs.max(), 500)

# Calculate best fit curve
mu_best = theor_distance_modulus(z_theory, H0_best, omega_l_best, 
                                 omega_m_best, omega_k_best)

# Calculate confidence intervals from MCMC samples
print("Computing 68% confidence bands...")
step = 10  # Use every 10th sample for speed
mu_samples = []

for i in range(0, len(H0_chain), step):
    mu_i = theor_distance_modulus(z_theory, H0_chain[i], omega_l_chain[i], 
                                  omega_m_chain[i], omega_k_chain[i])
    mu_samples.append(mu_i)

mu_samples = np.array(mu_samples)
mu_lower = np.percentile(mu_samples, 16, axis=0)
mu_upper = np.percentile(mu_samples, 84, axis=0)
print(f"Used {len(mu_samples)} samples for confidence bands\n")

# Plot results
fig, ax = plt.subplots(figsize=(12, 7))

# Data with error bars
ax.errorbar(zs, distance_modulus, yerr=error_distance_modulus, 
            fmt='o', color='darkblue', alpha=0.4, markersize=4,
            capsize=0, elinewidth=0.5, label='Union2.1 SNIa Data')

# Best fit line
ax.plot(z_theory, mu_best, '-', linewidth=2.5, 
        color='crimson', label='MCMC Best Fit', zorder=10)

# Confidence band
ax.fill_between(z_theory, mu_lower, mu_upper, 
                alpha=0.3, color='orange',
                label='68% Confidence Interval')

ax.set_xlabel('Redshift z', fontsize=14)
ax.set_ylabel('Distance Modulus μ', fontsize=14)
ax.set_title('MCMC Best Fit to Supernova Data', fontsize=15, fontweight='bold')
ax.legend(fontsize=12, loc='upper left')
ax.grid(True, alpha=0.3, linestyle='--')

plt.tight_layout()
plt.show()

# Calculate goodness of fit
mu_model = theor_distance_modulus(zs, H0_best, omega_l_best, 
                                  omega_m_best, omega_k_best)
chi2 = np.sum(((distance_modulus - mu_model) / error_distance_modulus)**2)
dof = len(zs) - 4  # 4 parameters
reduced_chi2 = chi2 / dof

print(f"Goodness of Fit:")
print(f"  χ² = {chi2:.2f}")
print(f"  Reduced χ² = {reduced_chi2:.4f}")
# Out:
# Using 6996 MCMC samples (after burn-in)
#
# Best Fit Parameters:
#   H0  = 66.61 ± 7.79 km/s/Mpc
#   Ω_Λ = 0.7365 ± 0.2309
#   Ω_M = 0.2679 ± 0.1039
#   Ω_k = 0.1386 ± 0.0892
#
# Computing 68% confidence bands...
# Used 700 samples for confidence bands
# Goodness of Fit:
#   χ² = 599.08
#   Reduced χ² = 1.0401
